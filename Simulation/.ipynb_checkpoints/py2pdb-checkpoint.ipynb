# %%
import os

# %%
bead_type_hash = {}
bead_type_hash["G"] = 2.25
bead_type_hash["A"] = 2.52
bead_type_hash["R"] = 3.28
bead_type_hash["K"] = 3.18
bead_type_hash["H"] = 3.04
bead_type_hash["D"] = 2.79
bead_type_hash["E"] = 2.96
bead_type_hash["S"] = 2.59
bead_type_hash["T"] = 2.81
bead_type_hash["N"] = 3.01
bead_type_hash["C"] = 2.74
bead_type_hash["P"] = 2.78
bead_type_hash["I"] = 3.09
bead_type_hash["M"] = 3.09
bead_type_hash["L"] = 3.09
bead_type_hash["F"] = 3.18
bead_type_hash["W"] = 3.39
bead_type_hash["Y"] = 3.23
bead_type_hash["V"] = 2.93

# %%
chain = "MASGRP"

# %%
def chain2bead(bead_type_hash, chain):
    bead_chain_list = {} #[backbone][side_bead]
    backbone_radius = 1.9
    x = 0
    bead_num = 1
    for bead in chain:
        side_bead_radius = bead_type_hash[bead]
        #backbone
        bead_chain_list[bead_num]= [(x,0,0)]
        bead_num += 1
        bead_chain_list[bead_num] = [(x,side_bead_radius+backbone_radius,0)]
        x = backbone_radius*2
        bead_num += 1
test = chain2bead(bead_type_hash, chain)
print(test)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /scratch/22343977/ipykernel_1733832/1579100291.py in <module>
#      12         x = backbone_radius*2
#      13         bead_num += 1
# ---> 14 test = chain2bead(bead_type_hash, chain)
#      15 print(test)
#      16
#
# /scratch/22343977/ipykernel_1733832/1579100291.py in chain2bead(bead_type_hash, chain)
#       7         side_bead_radius = bead_type_hash[bead]
#       8         #backbone
# ----> 9         bead_chain_list[bead_num]= [(x,0,0)]
#      10         bead_num += 1
#      11         bead_chain_list[bead_num] = [(x,side_bead_radius+backbone_radius,0)]
#
# IndexError: list assignment index out of range

# %% [raw]
# ATOM      1  PH    C     1    1472.830 750.961 758.851
# ATOM      2  RI    C     1    1471.773 747.063 756.602
# ATOM      3  C     C     1    1469.517 749.336 753.849
# ATOM      4  PH    A     2    1475.450 747.429 755.722
# ATOM      5  RI    A     2    1474.267 745.369 751.755
# ATOM      6  A     A     2    1471.642 749.041 750.001

# %%
def beads2pdb(chain, bead_list):
    with open(system.pdb, 'w') as file_object:
    
    for bead in chain

# %%
  fout1.write("{:6s}{:5d} {:^4s}{:1s}{:3s} {:1s}{:4d}{:1s}   {:8.3f}{:8.3f}{:8.3f}{:6.2f}{:6.2f}          {:>2s}\n".format(
                atomsring, atom_counter, expected_element, space, resname, chain, residue_id, space,
                x, y, z, occupancy, temp_factor, expected_element1))
# Out:
# '/projects/academic/nguyenh/shared/Neth/project2025/RNA'
